# %%
import cv2
import mediapipe
from math import sqrt
import numpy


video_capture = cv2.VideoCapture("1.mp4")
eye_state = "open"
eye_open = 0
eye_closed = 0
text = ''
while True:
    ret, frame = video_capture.read()
    
    if not ret:
        break

    frame = cv2.resize(frame, None, fx=1.5, fy=1.5, interpolation=cv2.INTER_CUBIC)
    frame_height, frame_width= frame.shape[:2]
    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_RGB2BGR)
    results  = face_mesh.process(rgb_frame)
    if results.multi_face_landmarks:
        frame_height, frame_width, dimension = frame.shape  # get frame things, dimension is not needed in our application

        landmarks = results.multi_face_landmarks[0].landmark          # get all landmark points in values                                      # if landmarks are found
        for id, landmark in enumerate(landmarks):        # use enumerate to get index and values
            x, y = landmark.x, landmark.y                # ladnmark points
            x_on_frame = int(x*frame_width)              # relative to frame width
            y_on_frame = int(y*frame_height)             # relative to frame height

            # draw point(circle) on each landmark to show (Optional) 
            if id == 145:
                lower_loc_right = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))

            elif id == 159:
                upper_loc_right = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))
                
            elif id == 374:
                lower_loc_left = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))
                
            elif id == 386:
                upper_loc_left = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))



        diff_left = int(lower_loc_left - upper_loc_left)
        diff_right = int(lower_loc_right - upper_loc_right)
        
        if (diff_left >= 20 and  diff_right >= 20) and eye_state == "closed":
            text = f'Eye Open'
            eye_state = "open"
            print(eye_state)
            print("left", diff_left)
            print("right", diff_right)
            eye_open +=1
        elif (diff_left <= 14 and  diff_right <= 14) and eye_state == "open":
            text = 'Eye Closed'
            eye_state = "closed"
            print(eye_state)
            print("left", diff_left)
            print("right", diff_right)
            eye_closed +=1
        cv2.putText(img = frame, 
					text = text, 
					org = (10, 100), 
					fontFace = cv2.FONT_HERSHEY_DUPLEX, 
					fontScale = 2, 
					color = (125, 246, 55),
					thickness = 3)

    cv2.imshow('Liveness Detection', frame)
    if cv2.waitKey(2) == 27:
        break

cv2.destroyAllWindows()
video_capture.release()
print("Eye Open: ", eye_open)
print("Eye Closed: ", eye_closed)
# Out:
# closed
# left 13
# right 14
# open
# left 20
# right 21
# closed
# left 12
# right 13
# open
# left 21
# right 22
# closed
# left 13
# right 14
# open
# left 20
# right 21
# Eye Open:  3
# Eye Closed:  3

# %%
import cv2
import mediapipe
from math import sqrt
import numpy


video_capture = cv2.VideoCapture("2.mp4")
eye_state = "open"
eye_open = 0
eye_closed = 0
text = ''
while True:
    ret, frame = video_capture.read()
    
    if not ret:
        break

    frame = cv2.resize(frame, None, fx=1.5, fy=1.5, interpolation=cv2.INTER_CUBIC)
    frame_height, frame_width= frame.shape[:2]
    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_RGB2BGR)
    results  = face_mesh.process(rgb_frame)
    if results.multi_face_landmarks:
        frame_height, frame_width, dimension = frame.shape  # get frame things, dimension is not needed in our application

        landmarks = results.multi_face_landmarks[0].landmark          # get all landmark points in values                                      # if landmarks are found
        for id, landmark in enumerate(landmarks):        # use enumerate to get index and values
            x, y = landmark.x, landmark.y                # ladnmark points
            x_on_frame = int(x*frame_width)              # relative to frame width
            y_on_frame = int(y*frame_height)             # relative to frame height

            # draw point(circle) on each landmark to show (Optional) 
            if id == 145:
                lower_loc_right = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))

            elif id == 159:
                upper_loc_right = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))
                
            elif id == 374:
                lower_loc_left = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))
                
            elif id == 386:
                upper_loc_left = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))



        diff_left = int(lower_loc_left - upper_loc_left)
        diff_right = int(lower_loc_right - upper_loc_right)
        
        if (diff_left >= 20 and  diff_right >= 20) and eye_state == "closed":
            text = f'Eye Open'
            eye_state = "open"
            print(eye_state)
            print("left", diff_left)
            print("right", diff_right)
            eye_open +=1
        elif (diff_left <= 14 and  diff_right <= 14) and eye_state == "open":
            text = 'Eye Closed'
            eye_state = "closed"
            print(eye_state)
            print("left", diff_left)
            print("right", diff_right)
            eye_closed +=1
        cv2.putText(img = frame, 
					text = text, 
					org = (10, 100), 
					fontFace = cv2.FONT_HERSHEY_DUPLEX, 
					fontScale = 2, 
					color = (125, 246, 55),
					thickness = 3)

    cv2.imshow('Liveness Detection', frame)
    if cv2.waitKey(2) == 27:
        break

cv2.destroyAllWindows()
video_capture.release()
print("Eye Open: ", eye_open)
print("Eye Closed: ", eye_closed)
# Out:
# closed
# left 14
# right 14
# open
# left 20
# right 20
# closed
# left 12
# right 12
# open
# left 20
# right 21
# closed
# left 13
# right 14
# open
# left 20
# right 20
# closed
# left 14
# right 14
# open
# left 20
# right 20
# closed
# left 13
# right 14
# open
# left 20
# right 21
# Eye Open:  5
# Eye Closed:  5

# %%
import cv2
import mediapipe
from math import sqrt
import numpy


video_capture = cv2.VideoCapture("3.mp4")
eye_state = "open"
eye_open = 0
eye_closed = 0
text = ''
while True:
    ret, frame = video_capture.read()
    
    if not ret:
        break

    frame = cv2.resize(frame, None, fx=1.5, fy=1.5, interpolation=cv2.INTER_CUBIC)
    frame_height, frame_width= frame.shape[:2]
    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_RGB2BGR)
    results  = face_mesh.process(rgb_frame)
    if results.multi_face_landmarks:
        frame_height, frame_width, dimension = frame.shape  # get frame things, dimension is not needed in our application

        landmarks = results.multi_face_landmarks[0].landmark          # get all landmark points in values                                      # if landmarks are found
        for id, landmark in enumerate(landmarks):        # use enumerate to get index and values
            x, y = landmark.x, landmark.y                # ladnmark points
            x_on_frame = int(x*frame_width)              # relative to frame width
            y_on_frame = int(y*frame_height)             # relative to frame height

            # draw point(circle) on each landmark to show (Optional) 
            if id == 145:
                lower_loc_right = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))

            elif id == 159:
                upper_loc_right = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))
                
            elif id == 374:
                lower_loc_left = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))
                
            elif id == 386:
                upper_loc_left = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))



        diff_left = int(lower_loc_left - upper_loc_left)
        diff_right = int(lower_loc_right - upper_loc_right)
        
        if (diff_left >= 20 and  diff_right >= 20) and eye_state == "closed":
            text = f'Eye Open'
            eye_state = "open"
            print(eye_state)
            print("left", diff_left)
            print("right", diff_right)
            eye_open +=1
        elif (diff_left <= 14 and  diff_right <= 14) and eye_state == "open":
            text = 'Eye Closed'
            eye_state = "closed"
            print(eye_state)
            print("left", diff_left)
            print("right", diff_right)
            eye_closed +=1
        cv2.putText(img = frame, 
					text = text, 
					org = (10, 100), 
					fontFace = cv2.FONT_HERSHEY_DUPLEX, 
					fontScale = 2, 
					color = (125, 246, 55),
					thickness = 3)

    cv2.imshow('Liveness Detection', frame)
    if cv2.waitKey(2) == 27:
        break

cv2.destroyAllWindows()
video_capture.release()
print("Eye Open: ", eye_open)
print("Eye Closed: ", eye_closed)
# Out:
# closed
# left 14
# right 14
# open
# left 21
# right 21
# closed
# left 14
# right 14
# open
# left 20
# right 20
# closed
# left 14
# right 14
# open
# left 21
# right 21
# closed
# left 14
# right 14
# open
# left 20
# right 20
# Eye Open:  4
# Eye Closed:  4

# %%
import cv2
import mediapipe
from math import sqrt
import numpy


video_capture = cv2.VideoCapture("4.mp4")
eye_state = "open"
eye_open = 0
eye_closed = 0
text = ''
while True:
    ret, frame = video_capture.read()
    
    if not ret:
        break

    frame = cv2.resize(frame, None, fx=1.5, fy=1.5, interpolation=cv2.INTER_CUBIC)
    frame_height, frame_width= frame.shape[:2]
    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_RGB2BGR)
    results  = face_mesh.process(rgb_frame)
    if results.multi_face_landmarks:
        frame_height, frame_width, dimension = frame.shape  # get frame things, dimension is not needed in our application

        landmarks = results.multi_face_landmarks[0].landmark          # get all landmark points in values                                      # if landmarks are found
        for id, landmark in enumerate(landmarks):        # use enumerate to get index and values
            x, y = landmark.x, landmark.y                # ladnmark points
            x_on_frame = int(x*frame_width)              # relative to frame width
            y_on_frame = int(y*frame_height)             # relative to frame height

            # draw point(circle) on each landmark to show (Optional) 
            if id == 145:
                lower_loc_right = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))

            elif id == 159:
                upper_loc_right = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))
                
            elif id == 374:
                lower_loc_left = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))
                
            elif id == 386:
                upper_loc_left = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))



        diff_left = int(lower_loc_left - upper_loc_left)
        diff_right = int(lower_loc_right - upper_loc_right)
        
        if (diff_left >= 20 and  diff_right >= 20) and eye_state == "closed":
            text = f'Eye Open'
            eye_state = "open"
            print(eye_state)
            print("left", diff_left)
            print("right", diff_right)
            eye_open +=1
        elif (diff_left <= 14 and  diff_right <= 14) and eye_state == "open":
            text = 'Eye Closed'
            eye_state = "closed"
            print(eye_state)
            print("left", diff_left)
            print("right", diff_right)
            eye_closed +=1
        cv2.putText(img = frame, 
					text = text, 
					org = (10, 100), 
					fontFace = cv2.FONT_HERSHEY_DUPLEX, 
					fontScale = 2, 
					color = (125, 246, 55),
					thickness = 3)

    cv2.imshow('Liveness Detection', frame)
    if cv2.waitKey(2) == 27:
        break

cv2.destroyAllWindows()
video_capture.release()
print("Eye Open: ", eye_open)
print("Eye Closed: ", eye_closed)
# Out:
# closed
# left 1
# right 3
# open
# left 21
# right 23
# Eye Open:  1
# Eye Closed:  1

# %%
import cv2
import mediapipe
from math import sqrt
import numpy


video_capture = cv2.VideoCapture("5.mp4")
eye_state = "open"
eye_open = 0
eye_closed = 0
text = ''
while True:
    ret, frame = video_capture.read()
    
    if not ret:
        break

    frame = cv2.resize(frame, None, fx=1.5, fy=1.5, interpolation=cv2.INTER_CUBIC)
    frame_height, frame_width= frame.shape[:2]
    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_RGB2BGR)
    results  = face_mesh.process(rgb_frame)
    if results.multi_face_landmarks:
        frame_height, frame_width, dimension = frame.shape  # get frame things, dimension is not needed in our application

        landmarks = results.multi_face_landmarks[0].landmark          # get all landmark points in values                                      # if landmarks are found
        for id, landmark in enumerate(landmarks):        # use enumerate to get index and values
            x, y = landmark.x, landmark.y                # ladnmark points
            x_on_frame = int(x*frame_width)              # relative to frame width
            y_on_frame = int(y*frame_height)             # relative to frame height

            # draw point(circle) on each landmark to show (Optional) 
            if id == 145:
                lower_loc_right = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))

            elif id == 159:
                upper_loc_right = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))
                
            elif id == 374:
                lower_loc_left = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))
                
            elif id == 386:
                upper_loc_left = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))



        diff_left = int(lower_loc_left - upper_loc_left)
        diff_right = int(lower_loc_right - upper_loc_right)
        
        if (diff_left >= 20 and  diff_right >= 20) and eye_state == "closed":
            text = f'Eye Open'
            eye_state = "open"
            print(eye_state)
            print("left", diff_left)
            print("right", diff_right)
            eye_open +=1
        elif (diff_left <= 14 and  diff_right <= 14) and eye_state == "open":
            text = 'Eye Closed'
            eye_state = "closed"
            print(eye_state)
            print("left", diff_left)
            print("right", diff_right)
            eye_closed +=1
        cv2.putText(img = frame, 
					text = text, 
					org = (10, 100), 
					fontFace = cv2.FONT_HERSHEY_DUPLEX, 
					fontScale = 2, 
					color = (125, 246, 55),
					thickness = 3)

    cv2.imshow('Liveness Detection', frame)
    if cv2.waitKey(2) == 27:
        break

cv2.destroyAllWindows()
video_capture.release()
print("Eye Open: ", eye_open)
print("Eye Closed: ", eye_closed)
# Out:
# closed
# left 8
# right 9
# open
# left 22
# right 23
# Eye Open:  1
# Eye Closed:  1

# %%
import cv2
import mediapipe
from math import sqrt
import numpy


video_capture = cv2.VideoCapture("6.mp4")
eye_state = "open"
eye_open = 0
eye_closed = 0
text = ''
while True:
    ret, frame = video_capture.read()
    
    if not ret:
        break

    frame = cv2.resize(frame, None, fx=1.5, fy=1.5, interpolation=cv2.INTER_CUBIC)
    frame_height, frame_width= frame.shape[:2]
    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_RGB2BGR)
    results  = face_mesh.process(rgb_frame)
    if results.multi_face_landmarks:
        frame_height, frame_width, dimension = frame.shape  # get frame things, dimension is not needed in our application

        landmarks = results.multi_face_landmarks[0].landmark          # get all landmark points in values                                      # if landmarks are found
        for id, landmark in enumerate(landmarks):        # use enumerate to get index and values
            x, y = landmark.x, landmark.y                # ladnmark points
            x_on_frame = int(x*frame_width)              # relative to frame width
            y_on_frame = int(y*frame_height)             # relative to frame height

            # draw point(circle) on each landmark to show (Optional) 
            if id == 145:
                lower_loc_right = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))

            elif id == 159:
                upper_loc_right = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))
                
            elif id == 374:
                lower_loc_left = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))
                
            elif id == 386:
                upper_loc_left = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))



        diff_left = int(lower_loc_left - upper_loc_left)
        diff_right = int(lower_loc_right - upper_loc_right)
        
        if (diff_left >= 20 and  diff_right >= 20) and eye_state == "closed":
            text = f'Eye Open'
            eye_state = "open"
            print(eye_state)
            print("left", diff_left)
            print("right", diff_right)
            eye_open +=1
        elif (diff_left <= 14 and  diff_right <= 14) and eye_state == "open":
            text = 'Eye Closed'
            eye_state = "closed"
            print(eye_state)
            print("left", diff_left)
            print("right", diff_right)
            eye_closed +=1
        cv2.putText(img = frame, 
					text = text, 
					org = (10, 100), 
					fontFace = cv2.FONT_HERSHEY_DUPLEX, 
					fontScale = 2, 
					color = (125, 246, 55),
					thickness = 3)

    cv2.imshow('Liveness Detection', frame)
    if cv2.waitKey(2) == 27:
        break

cv2.destroyAllWindows()
video_capture.release()
print("Eye Open: ", eye_open)
print("Eye Closed: ", eye_closed)
# Out:
# Eye Open:  0
# Eye Closed:  0

# %%
import cv2
import mediapipe
from math import sqrt
import numpy


video_capture = cv2.VideoCapture("7.mp4")
eye_state = "open"
eye_open = 0
eye_closed = 0
text = ''
while True:
    ret, frame = video_capture.read()
    
    if not ret:
        break

    frame = cv2.resize(frame, None, fx=1.5, fy=1.5, interpolation=cv2.INTER_CUBIC)
    frame_height, frame_width= frame.shape[:2]
    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_RGB2BGR)
    results  = face_mesh.process(rgb_frame)
    if results.multi_face_landmarks:
        frame_height, frame_width, dimension = frame.shape  # get frame things, dimension is not needed in our application

        landmarks = results.multi_face_landmarks[0].landmark          # get all landmark points in values                                      # if landmarks are found
        for id, landmark in enumerate(landmarks):        # use enumerate to get index and values
            x, y = landmark.x, landmark.y                # ladnmark points
            x_on_frame = int(x*frame_width)              # relative to frame width
            y_on_frame = int(y*frame_height)             # relative to frame height

            # draw point(circle) on each landmark to show (Optional) 
            if id == 145:
                lower_loc_right = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))

            elif id == 159:
                upper_loc_right = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))
                
            elif id == 374:
                lower_loc_left = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))
                
            elif id == 386:
                upper_loc_left = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))



        diff_left = int(lower_loc_left - upper_loc_left)
        diff_right = int(lower_loc_right - upper_loc_right)
        
        if (diff_left >= 20 and  diff_right >= 20) and eye_state == "closed":
            text = f'Eye Open'
            eye_state = "open"
            print(eye_state)
            print("left", diff_left)
            print("right", diff_right)
            eye_open +=1
        elif (diff_left <= 14 and  diff_right <= 14) and eye_state == "open":
            text = 'Eye Closed'
            eye_state = "closed"
            print(eye_state)
            print("left", diff_left)
            print("right", diff_right)
            eye_closed +=1
        cv2.putText(img = frame, 
					text = text, 
					org = (10, 100), 
					fontFace = cv2.FONT_HERSHEY_DUPLEX, 
					fontScale = 2, 
					color = (125, 246, 55),
					thickness = 3)

    cv2.imshow('Liveness Detection', frame)
    if cv2.waitKey(2) == 27:
        break

cv2.destroyAllWindows()
video_capture.release()
print("Eye Open: ", eye_open)
print("Eye Closed: ", eye_closed)
# Out:
# closed
# left 6
# right 6
# open
# left 23
# right 24
# Eye Open:  1
# Eye Closed:  1

# %%
import cv2
import mediapipe
from math import sqrt
import numpy


video_capture = cv2.VideoCapture("8.mp4")
eye_state = "open"
eye_open = 0
eye_closed = 0
text = ''
while True:
    ret, frame = video_capture.read()
    
    if not ret:
        break

    frame = cv2.resize(frame, None, fx=1.5, fy=1.5, interpolation=cv2.INTER_CUBIC)
    frame_height, frame_width= frame.shape[:2]
    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_RGB2BGR)
    results  = face_mesh.process(rgb_frame)
    if results.multi_face_landmarks:
        frame_height, frame_width, dimension = frame.shape  # get frame things, dimension is not needed in our application

        landmarks = results.multi_face_landmarks[0].landmark          # get all landmark points in values                                      # if landmarks are found
        for id, landmark in enumerate(landmarks):        # use enumerate to get index and values
            x, y = landmark.x, landmark.y                # ladnmark points
            x_on_frame = int(x*frame_width)              # relative to frame width
            y_on_frame = int(y*frame_height)             # relative to frame height

            # draw point(circle) on each landmark to show (Optional) 
            if id == 145:
                lower_loc_right = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))

            elif id == 159:
                upper_loc_right = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))
                
            elif id == 374:
                lower_loc_left = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))
                
            elif id == 386:
                upper_loc_left = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))



        diff_left = int(lower_loc_left - upper_loc_left)
        diff_right = int(lower_loc_right - upper_loc_right)
        
        if (diff_left >= 20 and  diff_right >= 20) and eye_state == "closed":
            text = f'Eye Open'
            eye_state = "open"
            print(eye_state)
            print("left", diff_left)
            print("right", diff_right)
            eye_open +=1
        elif (diff_left <= 14 and  diff_right <= 14) and eye_state == "open":
            text = 'Eye Closed'
            eye_state = "closed"
            print(eye_state)
            print("left", diff_left)
            print("right", diff_right)
            eye_closed +=1
        cv2.putText(img = frame, 
					text = text, 
					org = (10, 100), 
					fontFace = cv2.FONT_HERSHEY_DUPLEX, 
					fontScale = 2, 
					color = (125, 246, 55),
					thickness = 3)

    cv2.imshow('Liveness Detection', frame)
    if cv2.waitKey(2) == 27:
        break

cv2.destroyAllWindows()
video_capture.release()
print("Eye Open: ", eye_open)
print("Eye Closed: ", eye_closed)
# Out:
# closed
# left 12
# right 14
# open
# left 20
# right 21
# closed
# left 14
# right 14
# open
# left 20
# right 21
# closed
# left 13
# right 14
# open
# left 20
# right 21
# closed
# left 13
# right 14
# open
# left 20
# right 21
# closed
# left 14
# right 14
# open
# left 20
# right 20
# Eye Open:  5
# Eye Closed:  5

# %%
import cv2
import mediapipe
from math import sqrt
import numpy


video_capture = cv2.VideoCapture("9.mp4")
eye_state = "open"
eye_open = 0
eye_closed = 0
text = ''
while True:
    ret, frame = video_capture.read()
    
    if not ret:
        break

    frame = cv2.resize(frame, None, fx=1.5, fy=1.5, interpolation=cv2.INTER_CUBIC)
    frame_height, frame_width= frame.shape[:2]
    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_RGB2BGR)
    results  = face_mesh.process(rgb_frame)
    if results.multi_face_landmarks:
        frame_height, frame_width, dimension = frame.shape  # get frame things, dimension is not needed in our application

        landmarks = results.multi_face_landmarks[0].landmark          # get all landmark points in values                                      # if landmarks are found
        for id, landmark in enumerate(landmarks):        # use enumerate to get index and values
            x, y = landmark.x, landmark.y                # ladnmark points
            x_on_frame = int(x*frame_width)              # relative to frame width
            y_on_frame = int(y*frame_height)             # relative to frame height

            # draw point(circle) on each landmark to show (Optional) 
            # right
            if id == 145:
                lower_loc_right = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))

            elif id == 159:
                upper_loc_right = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))
            elif id == 158:
                upper_loc_right_second = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))
            elif id == 153:
                lower_loc_right_second = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))
            elif id == 157:
                upper_loc_right_third = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))
            elif id == 154:
                lower_loc_right_third = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))
            elif id == 160:
                upper_loc_right_fourth = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))
            elif id == 144:
                lower_loc_right_fourth = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))
            elif id == 161:
                upper_loc_right_fifth = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))
            elif id == 163:
                lower_loc_right_fifth = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))
            # left    
            elif id == 374:
                lower_loc_left = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))
                
            elif id == 386:
                upper_loc_left = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))
            elif id == 387:
                upper_loc_left_second = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))
                
            elif id == 373:
                lower_loc_left_second = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))
                
            elif id == 388:
                upper_loc_left_third = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))
                
            elif id == 390:
                lower_loc_left_third = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))
            elif id == 385:
                upper_loc_left_fourth = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))
                
            elif id == 380:
                lower_loc_left_fourth = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))
                
            elif id == 384:
                upper_loc_left_fifth = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))
                
            elif id == 381:
                lower_loc_left_fifth = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))




        diff_left = int((int(lower_loc_left - upper_loc_left) +
                        int(lower_loc_left_second - upper_loc_left_second) +
                        int(lower_loc_left_third - upper_loc_left_third) +
                        int(lower_loc_left_fourth - upper_loc_left_fourth) +
                        int(lower_loc_left_fifth - upper_loc_left_fifth)) / 5)
        diff_right = int((int(lower_loc_right - upper_loc_right) +
                        int(lower_loc_right_second - upper_loc_right_second) +
                        int(lower_loc_right_third - upper_loc_right_third) +
                        int(lower_loc_right_fourth - upper_loc_right_fourth) +
                        int(lower_loc_right_fifth - upper_loc_right_fifth)) / 5)
        
        if (diff_left >= 20 and  diff_right >= 20) and eye_state == "closed":
            text = f'Eye Open'
            eye_state = "open"
            print(eye_state)
            print("left", diff_left)
            print("right", diff_right)
            eye_open +=1
        elif (diff_left <= 14 and  diff_right <= 14) and eye_state == "open":
            text = 'Eye Closed'
            eye_state = "closed"
            print(eye_state)
            print("left", diff_left)
            print("right", diff_right)
            eye_closed +=1
        cv2.putText(img = frame, 
					text = text, 
					org = (10, 100), 
					fontFace = cv2.FONT_HERSHEY_DUPLEX, 
					fontScale = 2, 
					color = (125, 246, 55),
					thickness = 3)

    cv2.imshow('Liveness Detection', frame)
    if cv2.waitKey(2) == 27:
        break

cv2.destroyAllWindows()
video_capture.release()
print("Eye Open: ", eye_open)
print("Eye Closed: ", eye_closed)
# Out:
# closed
# left 10
# right 11
# open
# left 20
# right 20
# closed
# left 10
# right 11
# Eye Open:  1
# Eye Closed:  2

# %%
import cv2
import mediapipe
from math import sqrt
import numpy


video_capture = cv2.VideoCapture("10.mp4")
eye_state = "open"
eye_open = 0
eye_closed = 0
text = ''
while True:
    ret, frame = video_capture.read()
    
    if not ret:
        break

    frame = cv2.resize(frame, None, fx=1.5, fy=1.5, interpolation=cv2.INTER_CUBIC)
    frame_height, frame_width= frame.shape[:2]
    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_RGB2BGR)
    results  = face_mesh.process(rgb_frame)
    if results.multi_face_landmarks:
        frame_height, frame_width, dimension = frame.shape  # get frame things, dimension is not needed in our application

        landmarks = results.multi_face_landmarks[0].landmark          # get all landmark points in values                                      # if landmarks are found
        for id, landmark in enumerate(landmarks):        # use enumerate to get index and values
            x, y = landmark.x, landmark.y                # ladnmark points
            x_on_frame = int(x*frame_width)              # relative to frame width
            y_on_frame = int(y*frame_height)             # relative to frame height

            # draw point(circle) on each landmark to show (Optional) 
            # right
            if id == 145:
                lower_loc_right = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))

            elif id == 159:
                upper_loc_right = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))
            elif id == 158:
                upper_loc_right_second = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))
            elif id == 153:
                lower_loc_right_second = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))
            elif id == 157:
                upper_loc_right_third = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))
            elif id == 154:
                lower_loc_right_third = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))
            elif id == 160:
                upper_loc_right_fourth = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))
            elif id == 144:
                lower_loc_right_fourth = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))
            elif id == 161:
                upper_loc_right_fifth = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))
            elif id == 163:
                lower_loc_right_fifth = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))
            # left    
            elif id == 374:
                lower_loc_left = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))
                
            elif id == 386:
                upper_loc_left = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))
            elif id == 387:
                upper_loc_left_second = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))
                
            elif id == 373:
                lower_loc_left_second = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))
                
            elif id == 388:
                upper_loc_left_third = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))
                
            elif id == 390:
                lower_loc_left_third = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))
            elif id == 385:
                upper_loc_left_fourth = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))
                
            elif id == 380:
                lower_loc_left_fourth = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))
                
            elif id == 384:
                upper_loc_left_fifth = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))
                
            elif id == 381:
                lower_loc_left_fifth = y_on_frame
                cv2.circle(img=frame, center=(x_on_frame, y_on_frame), radius = 3, color=(0,255,0))




        diff_left = int((int(lower_loc_left - upper_loc_left) +
                        int(lower_loc_left_second - upper_loc_left_second) +
                        int(lower_loc_left_third - upper_loc_left_third) +
                        int(lower_loc_left_fourth - upper_loc_left_fourth) +
                        int(lower_loc_left_fifth - upper_loc_left_fifth)) / 5)
        diff_right = int((int(lower_loc_right - upper_loc_right) +
                        int(lower_loc_right_second - upper_loc_right_second) +
                        int(lower_loc_right_third - upper_loc_right_third) +
                        int(lower_loc_right_fourth - upper_loc_right_fourth) +
                        int(lower_loc_right_fifth - upper_loc_right_fifth)) / 5)
        
        if (diff_left >= 20 and  diff_right >= 20) and eye_state == "closed":
            text = f'Eye Open'
            eye_state = "open"
            print(eye_state)
            print("left", diff_left)
            print("right", diff_right)
            eye_open +=1
        elif (diff_left <= 14 and  diff_right <= 14) and eye_state == "open":
            text = 'Eye Closed'
            eye_state = "closed"
            print(eye_state)
            print("left", diff_left)
            print("right", diff_right)
            eye_closed +=1
        cv2.putText(img = frame, 
					text = text, 
					org = (10, 100), 
					fontFace = cv2.FONT_HERSHEY_DUPLEX, 
					fontScale = 2, 
					color = (125, 246, 55),
					thickness = 3)

    cv2.imshow('Liveness Detection', frame)
    if cv2.waitKey(2) == 27:
        break

cv2.destroyAllWindows()
video_capture.release()
print("Eye Open: ", eye_open)
print("Eye Closed: ", eye_closed)
# Out:
# closed
# left 11
# right 12
# open
# left 20
# right 21
# closed
# left 14
# right 14
# Eye Open:  1
# Eye Closed:  2
